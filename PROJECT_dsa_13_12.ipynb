# %% [markdown]
# # DATA CLEANING

# %%
#import the necessary libararies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import the data

# %%
data=pd.read_csv(r"D:\ad\tutorials\Data-analys\works\Prjt_report\my_project\wrking_dataset\data.csv")
data
# Out:
#                  id        date source  \
# 0      1.914948e+09  04-05-2017    nna
# 1      1.914948e+09  04-07-2017    nna
# 2      1.914948e+09   4/16/2017    nna
# 3      1.914948e+09   4/19/2017    nna
# 4      1.914948e+09  07-10-2016    nna
# ...             ...         ...    ...
# 11364  5.473000e+03         NaN    NaN
# 11365  3.408000e+03         NaN    NaN
# 11366  3.959000e+03         NaN    NaN
# 11367  2.253000e+03         NaN    NaN
# 11368  1.155000e+03         NaN    NaN
#
#                                                    title  \
# 0      Syria attack symptoms consistent with nerve ag...
# 1      Homs governor says U.S. attack caused deaths b...
# 2        Death toll from Aleppo bomb attack at least 112
# 3            Aleppo bomb blast kills six Syrian state TV
# 4      29 Syria Rebels Dead in Fighting for Key Alepp...
# ...                                                  ...
# 11364                                                NaN
# ...

# %%
data.shape
# Out:
# (11369, 20)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11369 entries, 0 to 11368
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 11073 non-null  float64
#  1   date               1100 non-null   object
#  2   source             804 non-null    object
#  3   title              1100 non-null   object
#  4   text               11369 non-null  object
#  5   author             10559 non-null  object
#  6   language           1100 non-null   object
#  7   location           10967 non-null  object
#  8   site_url           296 non-null    object
#  9   main_img_url       296 non-null    object
#  10  type               11369 non-null  object
#  11  subject            10263 non-null  object
#  12  author's title     7363 non-null   object
#  13  state              8055 non-null   object
#  14  party_affiliation  10263 non-null  object
#  15  barely_true        10263 non-null  float64
# ...

# %%
data.describe()
# Out:
#                  id   barely_true         FALSE     half_true   mostly_true  \
# count  1.107300e+04  10263.000000  10263.000000  10263.000000  10263.000000
# mean   1.405791e+08     11.549839     13.304394     17.168762     16.465166
# std    5.024323e+08     18.992224     24.132578     35.899983     36.202646
# min    1.000000e+00      0.000000      0.000000      0.000000      0.000000
# 25%    3.625000e+03      0.000000      0.000000      0.000000      0.000000
# 50%    7.307000e+03      2.000000      2.000000      3.000000      3.000000
# 75%    1.095500e+04     12.000000     15.000000     13.000000     11.000000
# max    1.965511e+09     70.000000    114.000000    160.000000    163.000000
#
#             on_fire
# count  10263.000000
# mean       6.202670
# std       16.121555
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        5.000000
# max      105.000000

# %%
#renaming column names
#df.rename(columns={"A": "a", "B": "c"})
data=data.rename(columns={"type":"label","main_img_url":"img_url","author's title":"author_title"})
data
# Out:
#                  id        date source  \
# 0      1.914948e+09  04-05-2017    nna
# 1      1.914948e+09  04-07-2017    nna
# 2      1.914948e+09   4/16/2017    nna
# 3      1.914948e+09   4/19/2017    nna
# 4      1.914948e+09  07-10-2016    nna
# ...             ...         ...    ...
# 11364  5.473000e+03         NaN    NaN
# 11365  3.408000e+03         NaN    NaN
# 11366  3.959000e+03         NaN    NaN
# 11367  2.253000e+03         NaN    NaN
# 11368  1.155000e+03         NaN    NaN
#
#                                                    title  \
# 0      Syria attack symptoms consistent with nerve ag...
# 1      Homs governor says U.S. attack caused deaths b...
# 2        Death toll from Aleppo bomb attack at least 112
# 3            Aleppo bomb blast kills six Syrian state TV
# 4      29 Syria Rebels Dead in Fighting for Key Alepp...
# ...                                                  ...
# 11364                                                NaN
# ...

# %%
data.columns
# Out:
# Index(['id', 'date', 'source', 'title', 'text', 'author', 'language',
#        'location', 'site_url', 'img_url', 'label', 'subject', 'author_title',
#        'state', 'party_affiliation', 'barely_true', 'FALSE', 'half_true',
#        'mostly_true', 'on_fire'],
#       dtype='object')

# %%
#moving the target feature to last 
data=data[['id', 'date', 'source', 'title', 'text', 'author', 'language',
       'location', 'site_url', 'img_url', 'subject',
       'author_title', 'state', 'party_affiliation', 'barely_true', 'FALSE',
       'half_true', 'mostly_true', 'on_fire','label']]

# %%
data['language'].unique()
# Out:
# array(['English', 'english', nan], dtype=object)

# %%
data.head()
# Out:
#              id        date source  \
# 0  1.914948e+09  04-05-2017    nna
# 1  1.914948e+09  04-07-2017    nna
# 2  1.914948e+09   4/16/2017    nna
# 3  1.914948e+09   4/19/2017    nna
# 4  1.914948e+09  07-10-2016    nna
#
#                                                title  \
# 0  Syria attack symptoms consistent with nerve ag...
# 1  Homs governor says U.S. attack caused deaths b...
# 2    Death toll from Aleppo bomb attack at least 112
# 3        Aleppo bomb blast kills six Syrian state TV
# 4  29 Syria Rebels Dead in Fighting for Key Alepp...
#
#                                                 text author language location  \
# 0  Wed 05 Apr 2017 Syria attack symptoms consiste...    NaN  English    idlib
# 1  Fri 07 Apr 2017 at 0914 Homs governor says U.S...    NaN  English     homs
# 2  Sun 16 Apr 2017 Death toll from Aleppo bomb at...    NaN  English   aleppo
# 3  Wed 19 Apr 2017 Aleppo bomb blast kills six Sy...    NaN  English   aleppo
# ...

# %%
#finding the duplicates

# %%
len(data[data.duplicated(keep='first')])
# Out:
# 22

# %%
data[data.duplicated(keep='first')]
# Out:
#                id        date source  \
# 463  1.926479e+09  11/18/2016   sana
# 464  1.926479e+09  11/18/2016   sana
# 868           NaN  26-10-2016    NaN
# 869           NaN  26-10-2016    NaN
# 870           NaN  26-10-2016    NaN
# 871           NaN  26-10-2016    NaN
# 878           NaN  27-10-2016    NaN
# 879           NaN  27-10-2016    NaN
# 880           NaN  27-10-2016    NaN
# 881           NaN  27-10-2016    NaN
# 899           NaN  29-10-2016    NaN
# 900           NaN  29-10-2016    NaN
# 901           NaN  29-10-2016    NaN
# 902           NaN  29-10-2016    NaN
# 903           NaN  29-10-2016    NaN
# 906           NaN  29-10-2016    NaN
# 907           NaN  29-10-2016    NaN
# 908           NaN  29-10-2016    NaN
# 918           NaN  31-10-2016    NaN
# 920           NaN  30-10-2016    NaN
# 922           NaN  30-10-2016    NaN
# 940           NaN  01-11-2016    NaN
#
#                                                  title  \
# ...

# %%
#drop the duplicates

# %%
data.drop_duplicates(keep='first',inplace=True)
# Out:
# C:\Users\ad-jma\AppData\Local\Temp\ipykernel_13308\1522144980.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop_duplicates(keep='first',inplace=True)

# %%
len(data[data.duplicated(keep='first')])
# Out:
# 0

# %%
data.head()
# Out:
#              id        date source  \
# 0  1.914948e+09  04-05-2017    nna
# 1  1.914948e+09  04-07-2017    nna
# 2  1.914948e+09   4/16/2017    nna
# 3  1.914948e+09   4/19/2017    nna
# 4  1.914948e+09  07-10-2016    nna
#
#                                                title  \
# 0  Syria attack symptoms consistent with nerve ag...
# 1  Homs governor says U.S. attack caused deaths b...
# 2    Death toll from Aleppo bomb attack at least 112
# 3        Aleppo bomb blast kills six Syrian state TV
# 4  29 Syria Rebels Dead in Fighting for Key Alepp...
#
#                                                 text author language location  \
# 0  Wed 05 Apr 2017 Syria attack symptoms consiste...    NaN  English    idlib
# 1  Fri 07 Apr 2017 at 0914 Homs governor says U.S...    NaN  English     homs
# 2  Sun 16 Apr 2017 Death toll from Aleppo bomb at...    NaN  English   aleppo
# 3  Wed 19 Apr 2017 Aleppo bomb blast kills six Sy...    NaN  English   aleppo
# ...

# %%
data.tail()
# Out:
#            id date source title  \
# 11364  5473.0  NaN    NaN   NaN
# 11365  3408.0  NaN    NaN   NaN
# 11366  3959.0  NaN    NaN   NaN
# 11367  2253.0  NaN    NaN   NaN
# 11368  1155.0  NaN    NaN   NaN
#
#                                                     text          author  \
# 11364  There are a larger number of shark attacks in ...    aclu-florida
# 11365  Democrats have now become the party of the [At...     alan-powell
# 11366  Says an alternative to Social Security that op...     herman-cain
# 11367  On lifting the U.S. Cuban embargo and allowing...     jeff-greene
# 11368  The Department of Veterans Affairs has a manua...  michael-steele
#
#       language                                           location site_url  \
# 11364      NaN                  interview on "The Colbert Report"      NaN
# 11365      NaN                                       an interview      NaN
# 11366      NaN                   a Republican presidential debate      NaN
# ...

# %%
#drop the  column id
data.drop('id',axis=1,inplace=True)
# Out:
# C:\Users\ad-jma\AppData\Local\Temp\ipykernel_13308\1519776475.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop('id',axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11347 entries, 0 to 11368
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               1078 non-null   object
#  1   source             802 non-null    object
#  2   title              1078 non-null   object
#  3   text               11347 non-null  object
#  4   author             10539 non-null  object
#  5   language           1078 non-null   object
#  6   location           10965 non-null  object
#  7   site_url           276 non-null    object
#  8   img_url            276 non-null    object
#  9   subject            10263 non-null  object
#  10  author_title       7363 non-null   object
#  11  state              8055 non-null   object
#  12  party_affiliation  10263 non-null  object
#  13  barely_true        10263 non-null  float64
#  14  FALSE              10263 non-null  float64
#  15  half_true          10263 non-null  float64
# ...

# %%
data.head()
# Out:
#          date source                                              title  \
# 0  04-05-2017    nna  Syria attack symptoms consistent with nerve ag...
# 1  04-07-2017    nna  Homs governor says U.S. attack caused deaths b...
# 2   4/16/2017    nna    Death toll from Aleppo bomb attack at least 112
# 3   4/19/2017    nna        Aleppo bomb blast kills six Syrian state TV
# 4  07-10-2016    nna  29 Syria Rebels Dead in Fighting for Key Alepp...
#
#                                                 text author language location  \
# 0  Wed 05 Apr 2017 Syria attack symptoms consiste...    NaN  English    idlib
# 1  Fri 07 Apr 2017 at 0914 Homs governor says U.S...    NaN  English     homs
# 2  Sun 16 Apr 2017 Death toll from Aleppo bomb at...    NaN  English   aleppo
# 3  Wed 19 Apr 2017 Aleppo bomb blast kills six Sy...    NaN  English   aleppo
# 4  Sun 10 Jul 2016 29 Syria Rebels Dead in Fighti...    NaN  English   aleppo
#
# ...

# %%
#splitting the column date
data[['date','month','year']]=data['date'].str.split('/',expand=True)
# Out:
# C:\Users\ad-jma\AppData\Local\Temp\ipykernel_13308\53501347.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[['date','month','year']]=data['date'].str.split('/',expand=True)
# C:\Users\ad-jma\AppData\Local\Temp\ipykernel_13308\53501347.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[['date','month','year']]=data['date'].str.split('/',expand=True)
# C:\Users\ad-jma\AppData\Local\Temp\ipykernel_13308\53501347.py:2: SettingWithCopyWarning:
# ...

# %%
#renaming date columns to day as we split date to day,month and year
data.rename(columns={'date':'day'},inplace=True)
# Out:
# C:\Users\ad-jma\AppData\Local\Temp\ipykernel_13308\1872028177.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.rename(columns={'date':'day'},inplace=True)

# %%
data.columns
# Out:
# Index(['day', 'source', 'title', 'text', 'author', 'language', 'location',
#        'site_url', 'img_url', 'subject', 'author_title', 'state',
#        'party_affiliation', 'barely_true', 'FALSE', 'half_true', 'mostly_true',
#        'on_fire', 'label', 'month', 'year'],
#       dtype='object')

# %%
data=data[['day','month','year','source', 'title', 'text', 'author', 'language', 'location',
       'site_url', 'img_url', 'subject', 'author_title', 'state',
       'party_affiliation', 'barely_true', 'FALSE', 'half_true', 'mostly_true',
       'on_fire','label']]

# %%
data.head()
# Out:
#           day month  year source  \
# 0  04-05-2017  None  None    nna
# 1  04-07-2017  None  None    nna
# 2           4    16  2017    nna
# 3           4    19  2017    nna
# 4  07-10-2016  None  None    nna
#
#                                                title  \
# 0  Syria attack symptoms consistent with nerve ag...
# 1  Homs governor says U.S. attack caused deaths b...
# 2    Death toll from Aleppo bomb attack at least 112
# 3        Aleppo bomb blast kills six Syrian state TV
# 4  29 Syria Rebels Dead in Fighting for Key Alepp...
#
#                                                 text author language location  \
# 0  Wed 05 Apr 2017 Syria attack symptoms consiste...    NaN  English    idlib
# 1  Fri 07 Apr 2017 at 0914 Homs governor says U.S...    NaN  English     homs
# 2  Sun 16 Apr 2017 Death toll from Aleppo bomb at...    NaN  English   aleppo
# 3  Wed 19 Apr 2017 Aleppo bomb blast kills six Sy...    NaN  English   aleppo
# ...

# %%
data.head()
# Out:
#           day month  year source  \
# 0  04-05-2017  None  None    nna
# 1  04-07-2017  None  None    nna
# 2           4    16  2017    nna
# 3           4    19  2017    nna
# 4  07-10-2016  None  None    nna
#
#                                                title  \
# 0  Syria attack symptoms consistent with nerve ag...
# 1  Homs governor says U.S. attack caused deaths b...
# 2    Death toll from Aleppo bomb attack at least 112
# 3        Aleppo bomb blast kills six Syrian state TV
# 4  29 Syria Rebels Dead in Fighting for Key Alepp...
#
#                                                 text author language location  \
# 0  Wed 05 Apr 2017 Syria attack symptoms consiste...    NaN  English    idlib
# 1  Fri 07 Apr 2017 at 0914 Homs governor says U.S...    NaN  English     homs
# 2  Sun 16 Apr 2017 Death toll from Aleppo bomb at...    NaN  English   aleppo
# 3  Wed 19 Apr 2017 Aleppo bomb blast kills six Sy...    NaN  English   aleppo
# ...

# %%
#fill the null values

# %%
data['language'].fillna('English',inplace=True)

# %%
data['language'].value_counts()
# Out:
# English    11071
# english      276
# Name: language, dtype: int64

# %%
data['language'].replace({'english':'English'},inplace=True)

# %%
data['language'].value_counts()
# Out:
# English    11347
# Name: language, dtype: int64

# %%
data['language'].unique()
# Out:
# array(['English'], dtype=object)

# %%
#fill the feature author

# %%
data['author'].fillna('anonymous',inplace=True)

# %%
data.tail()
# Out:
#        day month year source title  \
# 11364  NaN   NaN  NaN    NaN   NaN
# 11365  NaN   NaN  NaN    NaN   NaN
# 11366  NaN   NaN  NaN    NaN   NaN
# 11367  NaN   NaN  NaN    NaN   NaN
# 11368  NaN   NaN  NaN    NaN   NaN
#
#                                                     text          author  \
# 11364  There are a larger number of shark attacks in ...    aclu-florida
# 11365  Democrats have now become the party of the [At...     alan-powell
# 11366  Says an alternative to Social Security that op...     herman-cain
# 11367  On lifting the U.S. Cuban embargo and allowing...     jeff-greene
# 11368  The Department of Veterans Affairs has a manua...  michael-steele
#
#       language                                           location site_url  \
# 11364  English                  interview on "The Colbert Report"      NaN
# 11365  English                                       an interview      NaN
# 11366  English                   a Republican presidential debate      NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11347 entries, 0 to 11368
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   day                1078 non-null   object
#  1   month              437 non-null    object
#  2   year               437 non-null    object
#  3   source             802 non-null    object
#  4   title              1078 non-null   object
#  5   text               11347 non-null  object
#  6   author             11347 non-null  object
#  7   language           11347 non-null  object
#  8   location           10965 non-null  object
#  9   site_url           276 non-null    object
#  10  img_url            276 non-null    object
#  11  subject            10263 non-null  object
#  12  author_title       7363 non-null   object
#  13  state              8055 non-null   object
#  14  party_affiliation  10263 non-null  object
#  15  barely_true        10263 non-null  float64
# ...

# %%
#fill the feature month,year and day

# %%
data['month'].fillna(data['month'].mode()[0],inplace=True)
data['year'].fillna(data['year'].mode()[0],inplace=True)
data['day'].fillna(data['day'].mode()[0],inplace=True)

# %%
data.tail()
# Out:
#       day month  year source title  \
# 11364   8    15  2016    NaN   NaN
# 11365   8    15  2016    NaN   NaN
# 11366   8    15  2016    NaN   NaN
# 11367   8    15  2016    NaN   NaN
# 11368   8    15  2016    NaN   NaN
#
#                                                     text          author  \
# 11364  There are a larger number of shark attacks in ...    aclu-florida
# 11365  Democrats have now become the party of the [At...     alan-powell
# 11366  Says an alternative to Social Security that op...     herman-cain
# 11367  On lifting the U.S. Cuban embargo and allowing...     jeff-greene
# 11368  The Department of Veterans Affairs has a manua...  michael-steele
#
#       language                                           location site_url  \
# 11364  English                  interview on "The Colbert Report"      NaN
# 11365  English                                       an interview      NaN
# 11366  English                   a Republican presidential debate      NaN
# ...

# %%
data['source'].value_counts()
# Out:
# ahram            149
# manar            105
# alalam            90
# alaraby           84
# dailysabah        74
# sana              54
# sputnik           53
# etilaf            46
# trt               42
# jordantimes       28
# reuters           26
# arabiya           22
# nna               13
# asharqalawsat     11
# tass               5
# Name: source, dtype: int64

# %%
#fill the feature source

# %%
#our most dataaet rows the source website www.politifact.com so mentioning null data source values as politifact since 
#some of merged datasetrows doesnt have source column
data['source'].fillna('politifact',inplace=True)

# %%
data.isnull().sum()
# Out:
# day                      0
# month                    0
# year                     0
# source                   0
# title                10269
# text                     0
# author                   0
# language                 0
# location               382
# site_url             11071
# img_url              11071
# subject               1084
# author_title          3984
# state                 3292
# party_affiliation     1084
# barely_true           1084
# FALSE                 1084
# half_true             1084
# mostly_true           1084
# on_fire               1084
# label                    0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# day                      0
# month                    0
# year                     0
# source                   0
# title                10269
# text                     0
# author                   0
# language                 0
# location               382
# site_url             11071
# img_url              11071
# subject               1084
# author_title          3984
# state                 3292
# party_affiliation     1084
# barely_true           1084
# FALSE                 1084
# half_true             1084
# mostly_true           1084
# on_fire               1084
# label                    0
# dtype: int64

# %%
#fill the feature location

# %%
data['location'].value_counts()
# Out:
# aleppo                                                          306
# a news release                                                  242
# an interview                                                    229
# a press release                                                 223
# a speech                                                        216
#                                                                ...
# comments on MSNBC's "Daily Rundown"                               1
# a press release touting a state tourism program                   1
# Department of Homeland Security hearing                           1
# an appearance at the Brookings Institution                        1
# a televised debate on Miami's WPLG-10 against Kendrick Meek.      1
# Name: location, Length: 4367, dtype: int64

# %%
data['location'].fillna('unknown',inplace=True)

# %%
data.isnull().sum()
# Out:
# day                      0
# month                    0
# year                     0
# source                   0
# title                10269
# text                     0
# author                   0
# language                 0
# location                 0
# site_url             11071
# img_url              11071
# subject               1084
# author_title          3984
# state                 3292
# party_affiliation     1084
# barely_true           1084
# FALSE                 1084
# half_true             1084
# mostly_true           1084
# on_fire               1084
# label                    0
# dtype: int64

# %%
#fill the feature image_url and site_url with mode values of both the columns

# %%
data['site_url'].fillna(data['site_url'].mode()[0],inplace=True)
data['img_url'].fillna(data['img_url'].mode()[0],inplace=True)

# %%
data.isnull().sum()
# Out:
# day                      0
# month                    0
# year                     0
# source                   0
# title                10269
# text                     0
# author                   0
# language                 0
# location                 0
# site_url                 0
# img_url                  0
# subject               1084
# author_title          3984
# state                 3292
# party_affiliation     1084
# barely_true           1084
# FALSE                 1084
# half_true             1084
# mostly_true           1084
# on_fire               1084
# label                    0
# dtype: int64

# %%
#fill the feature subject null values with foreign values since most of dataset rows news data is international

# %%
data['subject'].fillna('foreign',inplace=True)

# %%
#fill the feature author_title

# %%
data['author_title'].fillna('not_specified',inplace=True)

# %%
data.head()
# Out:
#           day month  year source  \
# 0  04-05-2017    15  2016    nna
# 1  04-07-2017    15  2016    nna
# 2           4    16  2017    nna
# 3           4    19  2017    nna
# 4  07-10-2016    15  2016    nna
#
#                                                title  \
# 0  Syria attack symptoms consistent with nerve ag...
# 1  Homs governor says U.S. attack caused deaths b...
# 2    Death toll from Aleppo bomb attack at least 112
# 3        Aleppo bomb blast kills six Syrian state TV
# 4  29 Syria Rebels Dead in Fighting for Key Alepp...
#
#                                                 text     author language  \
# 0  Wed 05 Apr 2017 Syria attack symptoms consiste...  anonymous  English
# 1  Fri 07 Apr 2017 at 0914 Homs governor says U.S...  anonymous  English
# 2  Sun 16 Apr 2017 Death toll from Aleppo bomb at...  anonymous  English
# 3  Wed 19 Apr 2017 Aleppo bomb blast kills six Sy...  anonymous  English
# ...

# %%
#fill the feature state null values with Unknown. unknown is not used as in values 'Unknown' is already included for some

# %%
data['state'].fillna('Unknown',inplace=True)

# %%
data['state'].value_counts()
# Out:
# Unknown           3294
# Texas             1009
# Florida           1001
# Wisconsin          716
# New York           658
#                   ...
# Qatar                1
# ohio                 1
# Virginia             1
# United Kingdom       1
# Rhode Island         1
# Name: state, Length: 84, dtype: int64

# %%
data.isnull().sum()
# Out:
# day                      0
# month                    0
# year                     0
# source                   0
# title                10269
# text                     0
# author                   0
# language                 0
# location                 0
# site_url                 0
# img_url                  0
# subject                  0
# author_title             0
# state                    0
# party_affiliation     1084
# barely_true           1084
# FALSE                 1084
# half_true             1084
# mostly_true           1084
# on_fire               1084
# label                    0
# dtype: int64

# %%
data['state'].unique()
# Out:
# array(['Unknown', 'Texas', 'Virginia', 'Illinois', 'Florida', 'Wisconsin',
#        'New Jersey', 'Vermont', 'Massachusetts', 'Maryland',
#        'Washington, D.C. ', 'Oregon', 'New York', 'Washington, D.C.',
#        'California', 'Missouri', 'Rhode Island', 'West Virginia',
#        'Arkansas', 'New Hampshire', 'Ohio', 'Georgia', 'Arizona',
#        'Wyoming', 'Delaware', 'Kentucky', 'Kansas', 'ohio', 'Colorado',
#        'North Carolina', 'New Mexico', 'Illinois ', 'Alaska',
#        'South Carolina', 'Minnesota', 'Tennessee', 'Pennsylvania', 'Iowa',
#        'Connecticut', 'Louisiana', 'Indiana', 'Florida ', 'Utah',
#        'Michigan', 'Oklahoma', 'Nevada', 'Oregon ', 'Virgina', 'Nebraska',
#        'Georgia ', 'None', 'Washington D.C.', 'California ',
#        'Massachusetts ', 'Alabama', 'Russia', 'Washington state',
#        'Washington', 'District of Columbia', 'Colorado ',
#        'New Hampshire ', 'Mississippi', 'Rhode island', 'China',
# ...

# %%
data['state'].value_counts()
# Out:
# Unknown           3294
# Texas             1009
# Florida           1001
# Wisconsin          716
# New York           658
#                   ...
# Qatar                1
# ohio                 1
# Virginia             1
# United Kingdom       1
# Rhode Island         1
# Name: state, Length: 84, dtype: int64

# %%
#fill the column party affiliation null values with none
data['party_affiliation'].unique()
# Out:
# array([nan, 'republican', 'democrat', 'none', 'organization',
#        'independent', 'columnist', 'activist', 'talk-show-host',
#        'libertarian', 'newsmaker', 'journalist', 'labor-leader',
#        'state-official', 'business-leader', 'education-official',
#        'tea-party-member', 'green', 'liberal-party-canada',
#        'government-body', 'Moderate', 'democratic-farmer-labor',
#        'ocean-state-tea-party-action', 'constitution-party'], dtype=object)

# %%
data['party_affiliation'].fillna('none',inplace=True)

# %%
data.head()
# Out:
#           day month  year source  \
# 0  04-05-2017    15  2016    nna
# 1  04-07-2017    15  2016    nna
# 2           4    16  2017    nna
# 3           4    19  2017    nna
# 4  07-10-2016    15  2016    nna
#
#                                                title  \
# 0  Syria attack symptoms consistent with nerve ag...
# 1  Homs governor says U.S. attack caused deaths b...
# 2    Death toll from Aleppo bomb attack at least 112
# 3        Aleppo bomb blast kills six Syrian state TV
# 4  29 Syria Rebels Dead in Fighting for Key Alepp...
#
#                                                 text     author language  \
# 0  Wed 05 Apr 2017 Syria attack symptoms consiste...  anonymous  English
# 1  Fri 07 Apr 2017 at 0914 Homs governor says U.S...  anonymous  English
# 2  Sun 16 Apr 2017 Death toll from Aleppo bomb at...  anonymous  English
# 3  Wed 19 Apr 2017 Aleppo bomb blast kills six Sy...  anonymous  English
# ...

# %%
data['party_affiliation'].value_counts()
# Out:
# republican                      4508
# democrat                        3342
# none                            2830
# organization                     220
# independent                      148
# newsmaker                         58
# activist                          40
# libertarian                       40
# journalist                        38
# columnist                         36
# talk-show-host                    26
# state-official                    20
# labor-leader                      11
# tea-party-member                  10
# business-leader                    9
# green                              3
# education-official                 2
# liberal-party-canada               1
# government-body                    1
# Moderate                           1
# democratic-farmer-labor            1
# ocean-state-tea-party-action       1
# constitution-party                 1
# Name: party_affiliation, dtype: int64

# %%
data.tail()
# Out:
#       day month  year      source title  \
# 11364   8    15  2016  politifact   NaN
# 11365   8    15  2016  politifact   NaN
# 11366   8    15  2016  politifact   NaN
# 11367   8    15  2016  politifact   NaN
# 11368   8    15  2016  politifact   NaN
#
#                                                     text          author  \
# 11364  There are a larger number of shark attacks in ...    aclu-florida
# 11365  Democrats have now become the party of the [At...     alan-powell
# 11366  Says an alternative to Social Security that op...     herman-cain
# 11367  On lifting the U.S. Cuban embargo and allowing...     jeff-greene
# 11368  The Department of Veterans Affairs has a manua...  michael-steele
#
#       language                                           location  \
# 11364  English                  interview on "The Colbert Report"
# 11365  English                                       an interview
# 11366  English                   a Republican presidential debate
# ...

# %%
#backward filling
#bfill() is used to backward fill the missing values in the dataset. 
#It will backward fill the NaN values that are present in the pandas dataframe.
#When axis='rows', then value in current na cells are filled from the corresponding value in the next row. 
#If the next row is also na value then it won’t be populated.

# %%
data['barely_true'].fillna(method='backfill',inplace=True)

# %%
data['FALSE'].fillna(method='backfill',inplace=True)

# %%
data['half_true'].fillna(method='backfill',inplace=True)

# %%
data['mostly_true'].fillna(method='backfill',inplace=True)

# %%
data['on_fire'].fillna(method='backfill',inplace=True)

# %%
data.isnull().sum()
# Out:
# day                      0
# month                    0
# year                     0
# source                   0
# title                10269
# text                     0
# author                   0
# language                 0
# location                 0
# site_url                 0
# img_url                  0
# subject                  0
# author_title             0
# state                    0
# party_affiliation        0
# barely_true              0
# FALSE                    0
# half_true                0
# mostly_true              0
# on_fire                  0
# label                    0
# dtype: int64

# %%
data.head()
# Out:
#           day month  year source  \
# 0  04-05-2017    15  2016    nna
# 1  04-07-2017    15  2016    nna
# 2           4    16  2017    nna
# 3           4    19  2017    nna
# 4  07-10-2016    15  2016    nna
#
#                                                title  \
# 0  Syria attack symptoms consistent with nerve ag...
# 1  Homs governor says U.S. attack caused deaths b...
# 2    Death toll from Aleppo bomb attack at least 112
# 3        Aleppo bomb blast kills six Syrian state TV
# 4  29 Syria Rebels Dead in Fighting for Key Alepp...
#
#                                                 text     author language  \
# 0  Wed 05 Apr 2017 Syria attack symptoms consiste...  anonymous  English
# 1  Fri 07 Apr 2017 at 0914 Homs governor says U.S...  anonymous  English
# 2  Sun 16 Apr 2017 Death toll from Aleppo bomb at...  anonymous  English
# 3  Wed 19 Apr 2017 Aleppo bomb blast kills six Sy...  anonymous  English
# ...

# %%
data.tail()
# Out:
#       day month  year      source title  \
# 11364   8    15  2016  politifact   NaN
# 11365   8    15  2016  politifact   NaN
# 11366   8    15  2016  politifact   NaN
# 11367   8    15  2016  politifact   NaN
# 11368   8    15  2016  politifact   NaN
#
#                                                     text          author  \
# 11364  There are a larger number of shark attacks in ...    aclu-florida
# 11365  Democrats have now become the party of the [At...     alan-powell
# 11366  Says an alternative to Social Security that op...     herman-cain
# 11367  On lifting the U.S. Cuban embargo and allowing...     jeff-greene
# 11368  The Department of Veterans Affairs has a manua...  michael-steele
#
#       language                                           location  \
# 11364  English                  interview on "The Colbert Report"
# 11365  English                                       an interview
# 11366  English                   a Republican presidential debate
# ...

# %%
data['language'].unique()
# Out:
# array(['English'], dtype=object)

# %%
data['subject'].unique()
# Out:
# array(['foreign', 'abortion', 'energy,history,job-accomplishments', ...,
#        'animals,elections', 'retirement,social-security',
#        'florida,foreign-policy'], dtype=object)

# %%
#filling the title using the subject

# %%
#data['title'] = data.apply(lambda row: row['subject'] if pd.isna(row['title']) else row['title'], axis=1)
#data['title'].fillna(data['text'].apply(lambda x: x.split('.')[0] if pd.notnull(x) else x),inplace=True)

data['title'].fillna(data['text'].apply(lambda x: re.match(r'([A-Z][^\.!?]*[\ !?])', x).group(1) if pd.isna(x) else x),inplace=True)

# %%
data.tail()
# Out:
#       day month  year      source  \
# 11364   8    15  2016  politifact
# 11365   8    15  2016  politifact
# 11366   8    15  2016  politifact
# 11367   8    15  2016  politifact
# 11368   8    15  2016  politifact
#
#                                                    title  \
# 11364  There are a larger number of shark attacks in ...
# 11365  Democrats have now become the party of the [At...
# 11366  Says an alternative to Social Security that op...
# 11367  On lifting the U.S. Cuban embargo and allowing...
# 11368  The Department of Veterans Affairs has a manua...
#
#                                                     text          author  \
# 11364  There are a larger number of shark attacks in ...    aclu-florida
# 11365  Democrats have now become the party of the [At...     alan-powell
# 11366  Says an alternative to Social Security that op...     herman-cain
# 11367  On lifting the U.S. Cuban embargo and allowing...     jeff-greene
# ...

# %%
data.isnull().sum()
# Out:
# day                  0
# month                0
# year                 0
# source               0
# title                0
# text                 0
# author               0
# language             0
# location             0
# site_url             0
# img_url              0
# subject              0
# author_title         0
# state                0
# party_affiliation    0
# barely_true          0
# FALSE                0
# half_true            0
# mostly_true          0
# on_fire              0
# label                0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11347 entries, 0 to 11368
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   day                11347 non-null  object
#  1   month              11347 non-null  object
#  2   year               11347 non-null  object
#  3   source             11347 non-null  object
#  4   title              11347 non-null  object
#  5   text               11347 non-null  object
#  6   author             11347 non-null  object
#  7   language           11347 non-null  object
#  8   location           11347 non-null  object
#  9   site_url           11347 non-null  object
#  10  img_url            11347 non-null  object
#  11  subject            11347 non-null  object
#  12  author_title       11347 non-null  object
#  13  state              11347 non-null  object
#  14  party_affiliation  11347 non-null  object
#  15  barely_true        11347 non-null  float64
# ...

# %%
data['label'].unique()
# Out:
# array(['conspiracy', 'bias', 'fake', 'bs', 'FALSE', 'half-true',
#        'mostly-true', 'TRUE', 'barely-true', 'on-fire'], dtype=object)

# %%
#############################################reducing the target feature columns values and classifying the unique values
#into basically three

# %%
data['label']. replace(['FALSE','barely-true','bs'], 'fake', inplace=True)

# %%
data['label']. replace(['bias','half-true'], 'conspiracy', inplace=True)

# %%
data['label']. replace(['TRUE','mostly-true','on-fire'], 'genuine', inplace=True)

# %%
data['label'].unique()
# Out:
# array(['conspiracy', 'fake', 'genuine'], dtype=object)

# %%
#value counts
data['label'].value_counts()
# Out:
# genuine       4491
# fake          3772
# conspiracy    3084
# Name: label, dtype: int64

# %%
######################################33*********************************************************************************8

# %%
data.head()
# Out:
#           day month  year source  \
# 0  04-05-2017    15  2016    nna
# 1  04-07-2017    15  2016    nna
# 2           4    16  2017    nna
# 3           4    19  2017    nna
# 4  07-10-2016    15  2016    nna
#
#                                                title  \
# 0  Syria attack symptoms consistent with nerve ag...
# 1  Homs governor says U.S. attack caused deaths b...
# 2    Death toll from Aleppo bomb attack at least 112
# 3        Aleppo bomb blast kills six Syrian state TV
# 4  29 Syria Rebels Dead in Fighting for Key Alepp...
#
#                                                 text     author language  \
# 0  Wed 05 Apr 2017 Syria attack symptoms consiste...  anonymous  English
# 1  Fri 07 Apr 2017 at 0914 Homs governor says U.S...  anonymous  English
# 2  Sun 16 Apr 2017 Death toll from Aleppo bomb at...  anonymous  English
# 3  Wed 19 Apr 2017 Aleppo bomb blast kills six Sy...  anonymous  English
# ...

# %%
data.tail()
# Out:
#       day month  year      source  \
# 11364   8    15  2016  politifact
# 11365   8    15  2016  politifact
# 11366   8    15  2016  politifact
# 11367   8    15  2016  politifact
# 11368   8    15  2016  politifact
#
#                                                    title  \
# 11364  There are a larger number of shark attacks in ...
# 11365  Democrats have now become the party of the [At...
# 11366  Says an alternative to Social Security that op...
# 11367  On lifting the U.S. Cuban embargo and allowing...
# 11368  The Department of Veterans Affairs has a manua...
#
#                                                     text          author  \
# 11364  There are a larger number of shark attacks in ...    aclu-florida
# 11365  Democrats have now become the party of the [At...     alan-powell
# 11366  Says an alternative to Social Security that op...     herman-cain
# 11367  On lifting the U.S. Cuban embargo and allowing...     jeff-greene
# ...

# %%
data.isnull().sum()
# Out:
# day                  0
# month                0
# year                 0
# source               0
# title                0
# text                 0
# author               0
# language             0
# location             0
# site_url             0
# img_url              0
# subject              0
# author_title         0
# state                0
# party_affiliation    0
# barely_true          0
# FALSE                0
# half_true            0
# mostly_true          0
# on_fire              0
# label                0
# dtype: int64

# %%
data['title'].unique()
# Out:
# array(['Syria attack symptoms consistent with nerve agent use WHO',
#        'Homs governor says U.S. attack caused deaths but doesnt see big human losses',
#        'Death toll from Aleppo bomb attack at least 112', ...,
#        'Says an alternative to Social Security that operates in Galveston County, Texas, has meant that participants will retire with a whole lot more money than under Social Security.',
#        'On lifting the U.S. Cuban embargo and allowing travel to Cuba.',
#        "The Department of Veterans Affairs has a manual out there telling our veterans stuff like, 'Are you really of value to your community?' You know, encouraging them to commit suicide."],
#       dtype=object)

# %%
data['language'].unique()
# Out:
# array(['English'], dtype=object)

# %%
data['label'].unique()
# Out:
# array(['conspiracy', 'fake', 'genuine'], dtype=object)

# %%
#EXPLORATORY DATA ANALYSIS

# %%
#pairplot

# %%
sns.pairplot(data, hue ='label')
# to show
plt.show()

# %%
#count plot

sns.countplot(data=data, x="label")
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %%
#pie plot
kwargs = dict(
    startangle = 90,
    colormap   = 'autumn',
    fontsize   = 13,
    explode    = (0.1,0.1,0.1),
    figsize    = (60,5),
    autopct    = '%1.1f%%',
    title      = 'Label Value Counts'
)

data['label'].value_counts().plot.pie(**kwargs)
# Out:
# <Axes: title={'center': 'Label Value Counts'}, ylabel='label'>

# %%
plt.figure(figsize=(25,10))
sns.countplot(x='state',data=data,palette='viridis')
plt.tick_params(axis='x', which='both', bottom=False, top=False)
plt.xticks(rotation=45)
plt.xlabel('state')
plt.ylabel('count')
plt.title('which  state(country) was popular in fake news?')
plt.show()
plt.tight_layout()

# %%
sns.boxplot(data)
# Out:
# <Axes: >

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11347 entries, 0 to 11368
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   day                11347 non-null  object
#  1   month              11347 non-null  object
#  2   year               11347 non-null  object
#  3   source             11347 non-null  object
#  4   title              11347 non-null  object
#  5   text               11347 non-null  object
#  6   author             11347 non-null  object
#  7   language           11347 non-null  object
#  8   location           11347 non-null  object
#  9   site_url           11347 non-null  object
#  10  img_url            11347 non-null  object
#  11  subject            11347 non-null  object
#  12  author_title       11347 non-null  object
#  13  state              11347 non-null  object
#  14  party_affiliation  11347 non-null  object
#  15  barely_true        11347 non-null  float64
# ...

# %%
data.to_csv('data_new.csv',index=False)

# %%
data=pd.read_csv(r"D:\ad\tutorials\Data-analys\works\Prjt_report\my_project\wrking_dataset\data_new.csv")
data
# Out:
#               day  month  year      source  \
# 0      04-05-2017     15  2016         nna
# 1      04-07-2017     15  2016         nna
# 2               4     16  2017         nna
# 3               4     19  2017         nna
# 4      07-10-2016     15  2016         nna
# ...           ...    ...   ...         ...
# 11342           8     15  2016  politifact
# 11343           8     15  2016  politifact
# 11344           8     15  2016  politifact
# 11345           8     15  2016  politifact
# 11346           8     15  2016  politifact
#
#                                                    title  \
# 0      Syria attack symptoms consistent with nerve ag...
# 1      Homs governor says U.S. attack caused deaths b...
# 2        Death toll from Aleppo bomb attack at least 112
# 3            Aleppo bomb blast kills six Syrian state TV
# 4      29 Syria Rebels Dead in Fighting for Key Alepp...
# ...                                                  ...
# ...

# %%
sns.boxplot(data)
# Out:
# <Axes: >

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11347 entries, 0 to 11346
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   day                11347 non-null  object
#  1   month              11347 non-null  int64
#  2   year               11347 non-null  int64
#  3   source             11347 non-null  object
#  4   title              11347 non-null  object
#  5   text               11347 non-null  object
#  6   author             11347 non-null  object
#  7   language           11347 non-null  object
#  8   location           11347 non-null  object
#  9   site_url           11347 non-null  object
#  10  img_url            11347 non-null  object
#  11  subject            11347 non-null  object
#  12  author_title       11347 non-null  object
#  13  state              11347 non-null  object
#  14  party_affiliation  11347 non-null  object
#  15  barely_true        11347 non-null  float64
# ...

# %%
#Encoding
